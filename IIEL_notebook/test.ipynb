# %% [markdown]
# # IIEL Toolkit — Impacto Económico Local de Infraestructuras Energéticas
# Notebook interactivo para explorar, modificar y visualizar el índice IIEL.
# Usa pandas, geopandas y widgets para análisis y simulación.

# %%
import pandas as pd
import numpy as np
import tkinter as tk
from tkinter import filedialog, messagebox
import matplotlib.pyplot as plt
from math import radians, cos, sin, asin, sqrt
import folium
from IPython.display import display

def haversine(lat1, lon1, lat2, lon2):
    R = 6371
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat/2)**2 + cos(radians(lat1))*cos(radians(lat2))*sin(dlon/2)**2
    return 2*R*asin(sqrt(a))

print('Toolkit cargado correctamente')
# Out:
# Toolkit cargado correctamente
